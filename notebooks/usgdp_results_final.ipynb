# %% [markdown]
# # Results for US GDP

# %%
import sys
sys.path.append('../')
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from pathlib import Path
import src.usgdp_plot_functions as plot_funcs

# %%
results_dir = Path.cwd().parent/'results'
results_dir
# Out:
# PosixPath('/Users/guojeffrey/Documents/Nowcasting_with_signatures/results')

# %%
config_folder = 'signature_results'

# %%
# All new models to be plotted, for each model we need the respective "experiment_name" value from "default_sig_config.yaml"
new_models_for_plot = [
    ('final_run', 'Model 1'), # format: ('experiment_name', 'model label')
    ('...', 'Model 2'), # Replace '...' with actual experiment_name
    ('...', 'Model 3'),
    ('...', 'Model 4')
]
# no need to include DFM baseline (Model 5), which is automatically plotted

# %% [markdown]
# Plot the validation period

# %%
plot_funcs.plot_config(config_folder, new_models_for_plot,
                       pd.to_datetime('2010-01-01'), pd.to_datetime('2013-12-31'), save_dir='./',
                       filename='val_plot_pca1', results_dir=results_dir)
# Out:
# findfont: Font family ['Latin Modern Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Latin Modern Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Latin Modern Roman'] not found. Falling back to DejaVu Sans.
#              method      rmse
# 0           Model 1  1.496780
# 1           Model 2  1.422097
# 2           Model 3  1.459146
# 3           Model 4  1.615196
# 4  Model 5 Baseline  1.830514

# %% [markdown]
# Plot the testing period

# %%
plot_funcs.plot_config(config_folder, new_models_for_plot,
                       pd.to_datetime('2013-12-31'), pd.to_datetime('2024-01-31'), save_dir='./',
                       filename='test_plot_pca1', results_dir=results_dir)
# Out:
#              method      rmse
# 0           Model 1  6.709414
# 1           Model 2  6.781491
# 2           Model 3  6.797238
# 3           Model 4  9.164650
# 4  Model 5 Baseline  4.463496
